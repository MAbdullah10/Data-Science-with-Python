# %% [markdown]
# # Data Visualization
#  - Seabron automatically install following libraries <br>
#            - numpy<br>
#            - pandas<br>
#            - scipy<br>
#            - matplotlib<br>

# %% [markdown]
# ## Line Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
phool = sns.load_dataset("iris")
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#change figure size
plt.figure(figsize=(7,5)) 
#draw a line plot
sns.lineplot(x="sepal_length" , y="sepal_width", data=phool)
plt.plot("Flowers")
plt.xlim(4)
plt.ylim(2)
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
phool = sns.load_dataset("iris")

#set figure size
plt.figure(figsize=(7,5)) 

#draw a bar plot
sns.barplot(x="species" , y="petal_length", hue="species", data=phool)
plt.plot("Flowers")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
Kashti = sns.load_dataset("titanic")
Kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#set figure size
plt.figure(figsize=(7,5)) 

#draw a line plot
sns.barplot(x="sex" , y="alone", hue = "who", data=Kashti, order = ["female","male"])
plt.plot("")
plt.show()

# %%
#draw a bar plot
sns.barplot(x="sex" , y="alone", hue = "who", data=Kashti, color = "red", ci = None, order = ["female","male"], saturation = 0.7)
plt.plot("")
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_17992\875667763.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="sex" , y="alone", hue = "who", data=Kashti, color = "red", ci = None, order = ["female","male"], saturation = 0.7)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_17992\875667763.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.barplot(x="sex" , y="alone", hue = "who", data=Kashti, color = "red", ci = None, order = ["female","male"], saturation = 0.7)

# %% [markdown]
# ## Horizontal plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
Kashti = sns.load_dataset("titanic")

#just switch x and y axis from bar plot
sns.barplot(x="alone" , y="sex", hue = "who", palette = 'light:yellow', data=Kashti, saturation = 0.8)
plt.plot("")
plt.show()

# %% [markdown]
# ## Box plot

# %%
import seaborn
seaborn.set(style='whitegrid')
kashti = seaborn.load_dataset("titanic")
seaborn.boxplot(x="class", y="fare", data= kashti)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
import seaborn
seaborn.set(style='whitegrid')
tip = seaborn.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
seaborn.boxplot(x="tip", y="day", data= tip, color  = 'red' , saturation = 0.5)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
import pandas as pf
import numpy as np

sns.set(style='whitegrid')
tip = sns.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.describe()  #Explain basic info of the data
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
seaborn.boxplot(x="total_bill", data= tip, color  = '#8226d5') #color assignment using codes
# Out:
# <Axes: xlabel='total_bill'>

# %%
import matplotlib.pyplot as plt
seaborn.boxplot(x="tip", y="day", data= tip, color ='#39c637' , saturation = 0.5,
               showmeans = True, meanprops= {
                                            "marker" : "+",
                                            "markersize" : "12",
                                            "markeredgecolor" : "red"
               })
plt.xlabel ("Tip Given")
plt.ylabel ("Days")
plt.title("Tip given by Days", weight = "bold")
# Out:
# Text(0.5, 1.0, 'Tip given by Days')

# %%
import seaborn
nuqta = seaborn.load_dataset("dots")
nuqta
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="day", y="total_bill",
            hue="smoker", palette=["m", "g"],
            data=tips)
sns.despine(offset=10, trim=True)

# %% [markdown]
# ## Line Plot

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")

rs = np.random.RandomState(365)
values = rs.randn(365, 4).cumsum(axis=0)
dates = pd.date_range("1 1 2016", periods=365, freq="D")
data = pd.DataFrame(values, dates, columns=["A", "B", "C", "D"])
data = data.rolling(7).mean()

sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# <Axes: >

# %% [markdown]
# ## LinePlot with Multifacets

# %%
import seaborn
p = seaborn.color_palette('rocket_r')
seaborn.relplot(
    data = nuqta,
    x = "time",
    y = "firing_rate",
    hue = "coherence",
    size = "choice",
    col = "align",
    kind = "line", 
    size_order = ["T1","T2"],
    palette = p,
    height = 5,
    aspect = 0.75,
    facet_kws = dict(sharex = False)
)

# %% [markdown]
# ## Scatter Plot

# %%
import seaborn as sns
sns.set_theme(style="ticks")

df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the example planets dataset
planets = sns.load_dataset("planets")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data=planets,
    x="distance", y="orbital_period",
    hue="year", size="mass",
    palette=cmap, sizes=(10, 200),
)
g.set(xscale="log", yscale="log")
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True)

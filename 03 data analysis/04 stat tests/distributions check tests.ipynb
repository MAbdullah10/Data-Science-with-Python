# %% [markdown]
# # Distribution Check Tests

# %% [markdown]
# ### 01 Shapiro Wilk Test
# Test whether a dataset has normal distribution (guassian)

# %% [markdown]
# If p > 0.05 then the data is normal\
# Otherwise the data doesn't have normal or guassian distrbituion

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.stats import shapiro
data = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
stat, p = shapiro(data)
print('stat = %.3f, p = %.3f'% (stat,p))
if p > 0.05:
    print("The data is normal")
else:
    print("The data is not normal")
# Out:
# stat = 0.895, p = 0.193
# The data is normal

# %%
import pandas as pd
import numpy as np
import seaborn as sns

ks = sns.load_dataset("titanic")
sns.boxplot (ks['age'])
# Out:
# <Axes: ylabel='age'>

# %%
from scipy.stats import shapiro
stat, p = shapiro(ks['age'])
print('stat = %.3f, p = %.3f'% (stat,p))
if p > 0.05:
    print("The data is normal")
else:
    print("The data is not normal")
# Out:
# stat = nan, p = nan
# The data is not normal

# %%
from scipy.stats import shapiro
ks = ks.dropna()
stat, p = shapiro(ks['age'])
print('stat = %.3f, p = %.3f'% (stat,p))
if p > 0.05:
    print("The data is normal")
else:
    print("The data is not normal")
# Out:
# stat = 0.991, p = 0.284
# The data is normal

# %%
sns.boxplot(ks['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(ks['fare'])
# Out:
# <Axes: ylabel='fare'>

# %%
from scipy.stats import shapiro
ks = ks.dropna()
stat, p = shapiro(ks['fare'])
print('stat = %.3f, p = %.3f'% (stat,p))
if p > 0.05:
    print("The data is normal")
else:
    print("The data is not normal")
# Out:
# stat = 0.743, p = 0.000
# The data is not normal

# %%
ks['fare'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### 02 Correlation
#
# #### 01 Perason's Correlation Coefficient

# %% [markdown]
# Test whether two smaples have a linear relationship

# %%
from scipy.stats import pearsonr
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [-0.873, 2.817, 2.191, 0.950, 1.055, -0.436, -0.390, -1.78, 1.637, -0.869]
stat, p = pearsonr(data1, data2)
print('stat = %.3f, p = %.3f'% (stat,p))
if p > 0.05:
    print("Probably independent")
else:
    print("Dependent (Correlation exists)")
# Out:
# stat = 0.501, p = 0.140
# Probably independent

# %%
from scipy.stats import pearsonr
stat, p = pearsonr(ks['age'],ks['fare'])
print('stat = %.3f, p = %.3f'% (stat,p))
if p > 0.05:
    print("Probably independent")
else:
    print("Dependent (Correlation exists)")
# Out:
# stat = -0.091, p = 0.223
# Probably independent

# %% [markdown]
# #### 02 Spearsman's Ran Correlation
# Spearmans rank correlation coefficient is a measure of the strength and direction of the relationship between two variables

# %%
from scipy.stats import spearmanr
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [-0.873, 2.817, 2.191, 0.950, 1.055, -0.436, -0.390, -1.78, 1.637, -0.869]
stat, p = spearmanr(data1, data2)
print('stat = %.3f, p = %.3f'% (stat,p))
if p > 0.05:
    print("Probably independent")
else:
    print("Dependent (Correlation exists)")
# Out:
# stat = 0.345, p = 0.328
# Probably independent

# %%
from scipy.stats import spearmanr
stat, p = spearmanr(ks['age'],ks['fare'])
print('stat = %.3f, p = %.3f'% (stat,p))
if p > 0.05:
    print("Probably independent")
else:
    print("Dependent (Correlation exists)")
# Out:
# stat = -0.073, p = 0.330
# Probably independent

# %% [markdown]
# #### Difference
# - Assumption:	Requires normality in the data	No assumption of normality
# - Sensitivity to Outliers:	Sensitive to outliers	Less sensitive to outliers
# - Data Type:	Works with continuous data	Works with ordinal or continuous data

# %% [markdown]
# #### 03 Chi Squared Test
# The chi-squared test is a statistical test used to determine if there is a significant association between two categorical variables or not

# %%
from scipy.stats import chi2_contingency
table = [[10,20,30],[6,9,17]]
stat, p, dof, expected = chi2_contingency(table)
print('stat = %.3f, p = %.3f'% (stat,p))
if p > 0.05:
    print("Probably independent")
else:
    print("Dependent (Correlation exists)")
# Out:
# stat = 0.272, p = 0.873
# Probably independent

# %% [markdown]
# ### 03 Parametric Statistical Hypothesis Test
# #### 01 Student's T-Test
# The Student's T-Test is a statistical test used to determine if there is a significant difference between
# the means of two groups. It is commonly used in hypothesis testing to compare the means of two groups.

# %%
from scipy.stats import ttest_ind
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [-0.873, 2.817, 2.191, 0.950, 1.055, -0.436, -0.390, -1.78, 1.637, -0.869]
stat, p = ttest_ind(data1, data2)
print('stat = %.3f, p = %.3f'% (stat,p))
if p > 0.05:
    print("Probably same distribution")
else:
    print("Probably different distribution")
# Out:
# stat = -1.137, p = 0.271
# Probably same distribution

# %%
from scipy.stats import ttest_ind
stat, p = ttest_ind(ks['fare'],ks['age'])
print('stat = %.3f, p = %.3f'% (stat,p))
if p > 0.05:
    print("Probably same distribution")
else:
    print("Probably different distribution")
# Out:
# stat = 7.481, p = 0.000
# Probably different distribution

# %% [markdown]
# #### 02 Paired Student's T-Test
# The paired t-test is used to compare the means of two related groups of samples. It is used
# when the samples are paired or matched in some way, such as before and after a treatment, or
# between two different treatments.

# %%
from scipy.stats import ttest_rel
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [-0.873, 2.817, 2.191, 0.950, 1.055, -0.436, -0.390, -1.78, 1.637, -0.869]
stat, p = ttest_rel(data1, data2)
print('stat = %.3f, p = %.3f'% (stat,p))
if p > 0.05:
    print("Probably same distribution")
else:
    print("Probably different distribution")
# Out:
# stat = -1.609, p = 0.142
# Probably same distribution

# %%
from scipy.stats import ttest_rel
stat, p = ttest_rel(ks['fare'],ks['age'])
print('stat = %.3f, p = %.3f'% (stat,p))
if p > 0.05:
    print("Probably same distribution")
else:
    print("Probably different distribution")
# Out:
# stat = 7.351, p = 0.000
# Probably different distribution

# %% [markdown]
# ### 04 Analysis of Variance Test (ANOVA)
# The ANOVA test is used to compare the means of three or more groups to determine if there
# is a significant difference between them.

# %%
from scipy.stats import f_oneway
stat, p = f_oneway(ks['fare'],ks['age'], ks['survived'])
print('stat = %.3f, p = %.3f'% (stat,p))
if p > 0.05:
    print("Probably same distribution")
else:
    print("Probably different distribution")
# Out:
# stat = 137.590, p = 0.000
# Probably different distribution

# %%
from scipy.stats import f_oneway
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [-0.873, 2.817, 2.191, 0.950, 1.055, -0.436, -0.390, -1.78, 1.637, -0.869]
data3 = [-0.730, 0.817, 1.191, 0.950, -1.055, -0.436, -0.390, 0.708, 1.637, 0.869]
stat, p = f_oneway(data1, data2, data3)
print('stat = %.3f, p = %.3f'% (stat,p))
if p > 0.05:
    print("Probably same distribution")
else:
    print("Probably different distribution")
# Out:
# stat = 0.988, p = 0.385
# Probably same distribution

# %% [markdown]
# #### Post Hoc Test
# A post hoc test is a statistical test that is used to determine which pairs of groups are significantly different from each other after an ANOVA test has been performed. The post hoc test is used to determine which pairs of groups are significantly different from each other.
